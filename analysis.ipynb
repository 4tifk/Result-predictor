# %%
import pandas as pd

# %%
# read matches csv
matches = pd.read_csv("matches.csv", index_col=0)

# %%
# check if all matches are successfully scraped
matches["team"].value_counts()
# Out:
# team
# Liverpool                   76
# Arsenal                     76
# Manchester City             76
# Chelsea                     76
# Newcastle United            76
# Aston Villa                 76
# Nottingham Forest           76
# Brighton and Hove Albion    76
# Bournemouth                 76
# Brentford                   76
# Fulham                      76
# Crystal Palace              76
# Everton                     76
# West Ham United             76
# Manchester United           76
# Wolverhampton Wanderers     76
# Tottenham Hotspur           76
# Leicester City              38
# Ipswich Town                38
# Southampton                 38
# Luton Town                  38
# Burnley                     38
# Sheffield United            38
# Name: count, dtype: int64

# %%
# checking what types need to be changed
matches.dtypes
# Out:
# date              object
# time              object
# comp              object
# round             object
# day               object
# venue             object
# result            object
# gf                 int64
# ga                 int64
# opponent          object
# xg               float64
# xga              float64
# poss             float64
# attendance       float64
# captain           object
# formation         object
# opp formation     object
# referee           object
# match report      object
# notes            float64
# sh               float64
# sot              float64
# dist             float64
# fk               float64
# pk                 int64
# pkatt              int64
# season             int64
# team              object
# dtype: object

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches["target"] = (matches["result"] == "W").astype("int")

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < '2024-01-01']

# %%
test = matches[matches["date"] > '2024-01-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.5861456483126111

# %%
combined = pd.DataFrame(dict(actual=test["target"], prediction=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["prediction"])
# Out:
# prediction    0    1
# actual
# 0           539  163
# 1           303  121

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds)
# Out:
# 0.426056338028169

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Manchester City")

# %%
group
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 1  2024-08-18  16:30  Premier League   Matchweek 1  Sun  Away      W   2   0
# 2  2024-08-24  15:00  Premier League   Matchweek 2  Sat  Home      W   4   1
# 3  2024-08-31  17:30  Premier League   Matchweek 3  Sat  Away      W   3   1
# 4  2024-09-14  15:00  Premier League   Matchweek 4  Sat  Home      W   2   1
# 6  2024-09-22  16:30  Premier League   Matchweek 5  Sun  Home      D   2   2
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 51 2024-04-28  16:30  Premier League  Matchweek 35  Sun  Away      W   2   0
# 52 2024-05-04  17:30  Premier League  Matchweek 36  Sat  Home      W   5   1
# 53 2024-05-11  12:30  Premier League  Matchweek 37  Sat  Away      W   4   0
# 54 2024-05-14  20:00  Premier League  Matchweek 34  Tue  Away      W   2   0
# 55 2024-05-19  16:00  Premier League  Matchweek 38  Sun  Home      W   3   1
#
#            opponent  ...   fk  pk  pkatt  season             team venue_code  \
# 1           Chelsea  ...  0.0   0      0    2023  Manchester City          0
# 2      Ipswich Town  ...  1.0   1      1    2023  Manchester City          1
# 3          West Ham  ...  1.0   0      0    2023  Manchester City          0
# 4         Brentford  ...  0.0   0      0    2023  Manchester City          1
# 6           Arsenal  ...  1.0   0      0    2023  Manchester City          1
# ..              ...  ...  ...  ..    ...     ...              ...        ...
# 51  Nott'ham Forest  ...  1.0   0      0    2022  Manchester City          0
# 52           Wolves  ...  0.0   2      2    2022  Manchester City          1
# 53           Fulham  ...  0.0   1      1    2022  Manchester City          0
# 54        Tottenham  ...  0.0   1      1    2022  Manchester City          0
# 55         West Ham  ...  2.0   0      0    2022  Manchester City          1
#
#    opp_code hour day_code  target
# 1         6   16        6       1
# 2        10   15        5       1
# 3        21   17        5       1
# 4         3   15        5       1
# 6         0   16        6       0
# ..      ...  ...      ...     ...
# 51       17   16        6       1
# 52       22   17        5       1
# 53        9   12        5       1
# 54       20   20        1       1
# 55       21   16        6       1
#
# [76 rows x 33 columns]

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 5  2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      W   5   1
# 6  2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away      W   3   1
# 8  2023-09-23  15:00  Premier League   Matchweek 6  Sat  Home      W   2   0
# 10 2023-09-30  15:00  Premier League   Matchweek 7  Sat  Away      L   1   2
# 12 2023-10-08  16:30  Premier League   Matchweek 8  Sun  Away      L   0   1
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 50 2025-04-22  20:00  Premier League  Matchweek 34  Tue  Home      W   2   1
# 52 2025-05-02  20:00  Premier League  Matchweek 35  Fri  Home      W   1   0
# 53 2025-05-10  15:00  Premier League  Matchweek 36  Sat  Away      D   0   0
# 55 2025-05-20  20:00  Premier League  Matchweek 37  Tue  Home      W   3   1
# 56 2025-05-25  16:00  Premier League  Matchweek 38  Sun  Away      W   2   0
#
#            opponent  ...  day_code  target  gf_rolling  ga_rolling sh_rolling  \
# 5            Fulham  ...         5       1    2.000000    0.333333  20.000000
# 6          West Ham  ...         5       1    2.666667    0.666667  16.333333
# 8   Nott'ham Forest  ...         5       1    3.333333    1.000000  21.333333
# 10           Wolves  ...         5       0    3.333333    0.666667  14.000000
# 12          Arsenal  ...         6       0    2.000000    1.000000  19.666667
# ..              ...  ...       ...     ...         ...         ...        ...
# 50      Aston Villa  ...         1       1    2.333333    0.666667  14.000000
# 52           Wolves  ...         4       1    3.000000    1.000000  15.666667
# 53      Southampton  ...         5       0    1.666667    0.333333  11.666667
# 55      Bournemouth  ...         1       1    1.000000    0.333333  16.333333
# 56           Fulham  ...         6       1    1.333333    0.333333  15.666667
#
#    sot_rolling dist_rolling fk_rolling pk_rolling  pkatt_rolling
# 5     7.000000    16.366667   0.666667   0.000000       0.333333
# 6     5.666667    16.666667   0.666667   0.333333       0.666667
# 8     8.666667    16.166667   1.000000   0.333333       0.666667
# 10    7.000000    16.133333   1.000000   0.333333       0.333333
# 12    8.333333    17.633333   1.333333   0.000000       0.000000
# ..         ...          ...        ...        ...            ...
# 50    6.333333    17.500000   0.666667   0.000000       0.000000
# 52    6.666667    15.133333   0.333333   0.000000       0.000000
# 53    4.666667    16.766667   0.000000   0.000000       0.000000
# 55    4.000000    17.400000   0.666667   0.000000       0.000000
# 56    3.666667    19.500000   1.000000   0.000000       0.000000
#
# [73 rows x 41 columns]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
# Out:
# C:\Users\atifk\AppData\Local\Temp\ipykernel_24580\4052147919.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                  date   time            comp         round  \
# team
# Arsenal                 4  2023-09-03  16:30  Premier League   Matchweek 4
#                         5  2023-09-17  16:30  Premier League   Matchweek 5
#                         7  2023-09-24  14:00  Premier League   Matchweek 6
#                         9  2023-09-30  15:00  Premier League   Matchweek 7
#                         11 2023-10-08  16:30  Premier League   Matchweek 8
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 38 2025-04-26  15:00  Premier League  Matchweek 34
#                         39 2025-05-02  20:00  Premier League  Matchweek 35
#                         40 2025-05-10  15:00  Premier League  Matchweek 36
#                         41 2025-05-20  20:00  Premier League  Matchweek 37
#                         42 2025-05-25  16:00  Premier League  Matchweek 38
#
#                             day venue result  gf  ga         opponent  ...  \
# team                                                                   ...
# Arsenal                 4   Sun  Home      W   3   1   Manchester Utd  ...
#                         5   Sun  Away      W   1   0          Everton  ...
#                         7   Sun  Home      D   2   2        Tottenham  ...
#                         9   Sat  Away      W   4   0      Bournemouth  ...
#                         11  Sun  Home      W   1   0  Manchester City  ...
# ...                         ...   ...    ...  ..  ..              ...  ...
# Wolverhampton Wanderers 38  Sat  Home      W   3   0   Leicester City  ...
#                         39  Fri  Away      L   0   1  Manchester City  ...
#                         40  Sat  Home      L   0   2         Brighton  ...
#                         41  Tue  Away      L   2   4   Crystal Palace  ...
#                         42  Sun  Home      D   1   1        Brentford  ...
#
#                             day_code  target  gf_rolling  ga_rolling  \
# team
# Arsenal                 4          6       1    1.666667    1.000000
#                         5          6       1    2.000000    1.000000
#                         7          6       0    2.000000    1.000000
#                         9          5       1    2.000000    1.000000
#                         11         6       1    2.333333    0.666667
# ...                              ...     ...         ...         ...
# Wolverhampton Wanderers 38         5       1    2.333333    1.000000
#                         39         4       0    2.666667    0.666667
#                         40         5       0    1.333333    0.333333
#                         41         1       0    1.000000    1.000000
#                         42         6       0    0.666667    2.333333
#
#                            sh_rolling sot_rolling dist_rolling fk_rolling  \
# team
# Arsenal                 4   15.333333    6.000000    16.433333   0.000000
#                         5   16.000000    5.333333    15.066667   0.000000
#                         7   16.000000    6.000000    15.400000   0.000000
#                         9   14.000000    4.333333    16.433333   0.000000
#                         11  12.666667    4.666667    16.600000   0.000000
# ...                               ...         ...          ...        ...
# Wolverhampton Wanderers 38  13.000000    4.333333    16.433333   0.666667
#                         39  12.333333    4.000000    18.633333   1.000000
#                         40  10.000000    2.333333    18.900000   0.666667
#                         41  12.000000    2.666667    17.200000   0.333333
#                         42   9.333333    2.000000    15.633333   0.000000
#
#                            pk_rolling  pkatt_rolling
# team
# Arsenal                 4    0.666667       0.666667
#                         5    0.666667       0.666667
#                         7    0.333333       0.333333
#                         9    0.333333       0.333333
#                         11   1.000000       1.000000
# ...                               ...            ...
# Wolverhampton Wanderers 38   0.000000       0.000000
#                         39   0.000000       0.000000
#                         40   0.000000       0.000000
#                         41   0.000000       0.000000
#                         42   0.000000       0.000000
#
# [1451 rows x 41 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 4  2023-09-03  16:30  Premier League   Matchweek 4  Sun  Home      W   3   1
# 5  2023-09-17  16:30  Premier League   Matchweek 5  Sun  Away      W   1   0
# 7  2023-09-24  14:00  Premier League   Matchweek 6  Sun  Home      D   2   2
# 9  2023-09-30  15:00  Premier League   Matchweek 7  Sat  Away      W   4   0
# 11 2023-10-08  16:30  Premier League   Matchweek 8  Sun  Home      W   1   0
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 38 2025-04-26  15:00  Premier League  Matchweek 34  Sat  Home      W   3   0
# 39 2025-05-02  20:00  Premier League  Matchweek 35  Fri  Away      L   0   1
# 40 2025-05-10  15:00  Premier League  Matchweek 36  Sat  Home      L   0   2
# 41 2025-05-20  20:00  Premier League  Matchweek 37  Tue  Away      L   2   4
# 42 2025-05-25  16:00  Premier League  Matchweek 38  Sun  Home      D   1   1
#
#            opponent  ...  day_code  target  gf_rolling  ga_rolling sh_rolling  \
# 4    Manchester Utd  ...         6       1    1.666667    1.000000  15.333333
# 5           Everton  ...         6       1    2.000000    1.000000  16.000000
# 7         Tottenham  ...         6       0    2.000000    1.000000  16.000000
# 9       Bournemouth  ...         5       1    2.000000    1.000000  14.000000
# 11  Manchester City  ...         6       1    2.333333    0.666667  12.666667
# ..              ...  ...       ...     ...         ...         ...        ...
# 38   Leicester City  ...         5       1    2.333333    1.000000  13.000000
# 39  Manchester City  ...         4       0    2.666667    0.666667  12.333333
# 40         Brighton  ...         5       0    1.333333    0.333333  10.000000
# 41   Crystal Palace  ...         1       0    1.000000    1.000000  12.000000
# 42        Brentford  ...         6       0    0.666667    2.333333   9.333333
#
#    sot_rolling dist_rolling fk_rolling pk_rolling  pkatt_rolling
# 4     6.000000    16.433333   0.000000   0.666667       0.666667
# 5     5.333333    15.066667   0.000000   0.666667       0.666667
# 7     6.000000    15.400000   0.000000   0.333333       0.333333
# 9     4.333333    16.433333   0.000000   0.333333       0.333333
# 11    4.666667    16.600000   0.000000   1.000000       1.000000
# ..         ...          ...        ...        ...            ...
# 38    4.333333    16.433333   0.666667   0.000000       0.000000
# 39    4.000000    18.633333   1.000000   0.000000       0.000000
# 40    2.333333    18.900000   0.666667   0.000000       0.000000
# 41    2.666667    17.200000   0.333333   0.000000       0.000000
# 42    2.000000    15.633333   0.000000   0.000000       0.000000
#
# [1451 rows x 41 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2024-01-01']
    test = data[data["date"] > '2024-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    precision = precision_score(test["target"], preds)
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.5117647058823529

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
combined
# Out:
#       actual  predicted       date                     team         opponent  \
# 17         1          0 2024-01-20                  Arsenal   Crystal Palace
# 18         1          1 2024-01-30                  Arsenal  Nott'ham Forest
# 19         1          1 2024-02-04                  Arsenal        Liverpool
# 20         1          0 2024-02-11                  Arsenal         West Ham
# 21         1          1 2024-02-17                  Arsenal          Burnley
# ...      ...        ...        ...                      ...              ...
# 1446       1          1 2025-04-26  Wolverhampton Wanderers   Leicester City
# 1447       0          0 2025-05-02  Wolverhampton Wanderers  Manchester City
# 1448       0          0 2025-05-10  Wolverhampton Wanderers         Brighton
# 1449       0          0 2025-05-20  Wolverhampton Wanderers   Crystal Palace
# 1450       0          0 2025-05-25  Wolverhampton Wanderers        Brentford
#
#      result
# 17        W
# 18        W
# 19        W
# 20        W
# 21        W
# ...     ...
# 1446      W
# 1447      L
# 1448      L
# 1449      L
# 1450      D
#
# [1117 rows x 6 columns]

# %%
# normalise names
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {
"Brighton and Hove Albion": "Brighton",
"Manchester United": "Manchester Utd",
"Newcastle United": "Newcastle Utd",
"Tottenham Hotspur": "Tottenham",
"West Ham United": "West Ham",
"Wolverhampton Wanderers": "Wolves"
}

mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
combined
# Out:
#       actual  predicted       date                     team         opponent  \
# 17         1          0 2024-01-20                  Arsenal   Crystal Palace
# 18         1          1 2024-01-30                  Arsenal  Nott'ham Forest
# 19         1          1 2024-02-04                  Arsenal        Liverpool
# 20         1          0 2024-02-11                  Arsenal         West Ham
# 21         1          1 2024-02-17                  Arsenal          Burnley
# ...      ...        ...        ...                      ...              ...
# 1446       1          1 2025-04-26  Wolverhampton Wanderers   Leicester City
# 1447       0          0 2025-05-02  Wolverhampton Wanderers  Manchester City
# 1448       0          0 2025-05-10  Wolverhampton Wanderers         Brighton
# 1449       0          0 2025-05-20  Wolverhampton Wanderers   Crystal Palace
# 1450       0          0 2025-05-25  Wolverhampton Wanderers        Brentford
#
#      result new_team
# 17        W  Arsenal
# 18        W  Arsenal
# 19        W  Arsenal
# 20        W  Arsenal
# 21        W  Arsenal
# ...     ...      ...
# 1446      W   Wolves
# 1447      L   Wolves
# 1448      L   Wolves
# 1449      L   Wolves
# 1450      D   Wolves
#
# [1117 rows x 7 columns]

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "oponent"])
